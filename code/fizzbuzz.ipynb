# %% [markdown]
# <a href="https://colab.research.google.com/github/eliholton7/Ev288/blob/main/code/fizzbuzz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fizzbuzz
#
# Fizzbuzz is an introductory software engineering exercise that demonstrates
# concepts of loops and conditional statements.

# %% [markdown]
# ## Goal
# A successful fizzbuzz solution does the following:
# 1. Loop from 1 to 100
# 2. If the iteration is divisible by 3, print "fizz"
# 3. If the iteration is divisible by 5, print "buzz"
# 4. If the iteration is divisible by 3 AND 5, print "fizzbuzz"
# 5. In any other case, don't print anything and continue
#
# **ACTIVITY: Implement your fizzbuzz solution below!**

# %%
# Implement your fizzbuzz solution here
loop_range = range(1,101)
for i in loop_range:
  if i % 3 == 0 and i % 5 == 0:
    print("fizzbuzz")
  elif i % 3 == 0:
    print("fizz")
  elif i % 5 == 0:
    print("buzz")
  print(i)
# Out:
# 1
# 2
# fizz
# 3
# 4
# buzz
# 5
# fizz
# 6
# 7
# 8
# fizz
# 9
# buzz
# 10
# 11
# fizz
# 12
# 13
# 14
# fizzbuzz
# 15
# 16
# 17
# fizz
# 18
# 19
# buzz
# 20
# fizz
# 21
# 22
# 23
# fizz
# 24
# buzz
# 25
# 26
# fizz
# 27
# 28
# 29
# fizzbuzz
# 30
# 31
# 32
# fizz
# 33
# 34
# buzz
# 35
# fizz
# 36
# 37
# 38
# fizz
# 39
# buzz
# 40
# 41
# fizz
# 42
# 43
# 44
# fizzbuzz
# 45
# 46
# 47
# fizz
# 48
# 49
# buzz
# 50
# fizz
# 51
# 52
# 53
# fizz
# 54
# buzz
# 55
# 56
# fizz
# 57
# 58
# 59
# fizzbuzz
# 60
# 61
# 62
# fizz
# 63
# 64
# buzz
# 65
# fizz
# 66
# 67
# 68
# fizz
# 69
# buzz
# 70
# 71
# fizz
# 72
# 73
# 74
# fizzbuzz
# 75
# 76
# 77
# fizz
# 78
# 79
# buzz
# 80
# fizz
# 81
# 82
# 83
# fizz
# 84
# buzz
# 85
# 86
# fizz
# 87
# 88
# 89
# fizzbuzz
# 90
# 91
# 92
# fizz
# 93
# 94
# buzz
# 95
# fizz
# 96
# 97
# 98
# fizz
# 99
# buzz
# 100
